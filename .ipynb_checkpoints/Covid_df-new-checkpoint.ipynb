# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
import datetime as dt

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that "admin" database is in MongoDb
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'coviddatadb', 'customerdb', 'fruits_db', 'gardenDB', 'local', 'test_class', 'travel_db', 'uk_food']

# %%
# assign the admin database to a variable name
db = mongo['coviddatadb']

# %%
# review the collections (tables) in our database
print(db.list_collection_names())
# Out:
# ['cleanedcoviddata']

# %%
# assign the collection to a variable
covid_data = db['cleanedcoviddata']

# %% [markdown]
# # Clean the Data

# %%
# Retrieve data from the MongoDB collection
results = covid_data.find()

# %%
# Create a Pandas DataFrame
df = pd.DataFrame(results)

# %%
# Print the number of rows in the DataFrame
print('rows in DataFrame:', len(df))
# Out:
# rows in DataFrame: 330696

# %%
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#                         _id iso_code continent     location        date  \
# 0  64d910440e69a590d76a008b      AFG      Asia  Afghanistan  03/01/2020
# 1  64d910440e69a590d76a008c      AFG      Asia  Afghanistan  04/01/2020
# 2  64d910440e69a590d76a008d      AFG      Asia  Afghanistan  05/01/2020
# 3  64d910440e69a590d76a008e      AFG      Asia  Afghanistan  06/01/2020
# 4  64d910440e69a590d76a008f      AFG      Asia  Afghanistan  07/01/2020
# 5  64d910440e69a590d76a0090      AFG      Asia  Afghanistan  08/01/2020
# 6  64d910440e69a590d76a0091      AFG      Asia  Afghanistan  09/01/2020
# 7  64d910440e69a590d76a0092      AFG      Asia  Afghanistan  10/01/2020
# 8  64d910440e69a590d76a0093      AFG      Asia  Afghanistan  11/01/2020
# 9  64d910440e69a590d76a0094      AFG      Asia  Afghanistan  12/01/2020
#
#    stringency_index  median_age  gdp_per_capita  handwashing_facilities  \
# 0               0.0        18.6        1803.987                  37.746
# 1               0.0        18.6        1803.987                  37.746
# 2               0.0        18.6        1803.987                  37.746
# 3               0.0        18.6        1803.987                  37.746
# 4               0.0        18.6        1803.987                  37.746
# 5               0.0        18.6        1803.987                  37.746
# 6               0.0        18.6        1803.987                  37.746
# 7               0.0        18.6        1803.987                  37.746
# 8               0.0        18.6        1803.987                  37.746
# 9               0.0        18.6        1803.987                  37.746
#
#    total_cases  total_cases_per_million  total_vaccinations  \
# 0          NaN                      NaN                 NaN
# 1          NaN                      NaN                 NaN
# 2          NaN                      NaN                 NaN
# 3          NaN                      NaN                 NaN
# 4          NaN                      NaN                 NaN
# 5          NaN                      NaN                 NaN
# 6          NaN                      NaN                 NaN
# 7          NaN                      NaN                 NaN
# 8          NaN                      NaN                 NaN
# 9          NaN                      NaN                 NaN
#
#    people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                NaN                      NaN             NaN
# 1                NaN                      NaN             NaN
# 2                NaN                      NaN             NaN
# 3                NaN                      NaN             NaN
# 4                NaN                      NaN             NaN
# 5                NaN                      NaN             NaN
# 6                NaN                      NaN             NaN
# 7                NaN                      NaN             NaN
# 8                NaN                      NaN             NaN
# 9                NaN                      NaN             NaN
#
#    total_boosters_per_hundred  female_smokers  male_smokers
# 0                         NaN             NaN           NaN
# 1                         NaN             NaN           NaN
# 2                         NaN             NaN           NaN
# 3                         NaN             NaN           NaN
# 4                         NaN             NaN           NaN
# 5                         NaN             NaN           NaN
# 6                         NaN             NaN           NaN
# 7                         NaN             NaN           NaN
# 8                         NaN             NaN           NaN
# 9                         NaN             NaN           NaN

# %%
# Examine data type of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330696 entries, 0 to 330695
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   _id                         330696 non-null  object
#  1   iso_code                    330696 non-null  object
#  2   continent                   315000 non-null  object
#  3   location                    330696 non-null  object
#  4   date                        330696 non-null  object
#  5   stringency_index            197651 non-null  float64
#  6   median_age                  261029 non-null  float64
#  7   gdp_per_capita              255826 non-null  float64
#  8   handwashing_facilities      125570 non-null  float64
#  9   total_cases                 293300 non-null  float64
#  10  total_cases_per_million     293300 non-null  float64
#  11  total_vaccinations          77350 non-null   float64
#  12  people_vaccinated           74071 non-null   float64
#  13  people_fully_vaccinated     70622 non-null   float64
#  14  total_boosters              45761 non-null   float64
#  15  total_boosters_per_hundred  45761 non-null   float64
#  16  female_smokers              192280 non-null  float64
#  17  male_smokers                189664 non-null  float64
# dtypes: float64(13), object(5)
# memory usage: 45.4+ MB

# %%
# Change data types for data analysis
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')

# %%
# Confirm type changes were successful by examining data types again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330696 entries, 0 to 330695
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   _id                         330696 non-null  object
#  1   iso_code                    330696 non-null  object
#  2   continent                   315000 non-null  object
#  3   location                    330696 non-null  object
#  4   date                        330696 non-null  datetime64[ns]
#  5   stringency_index            197651 non-null  float64
#  6   median_age                  261029 non-null  float64
#  7   gdp_per_capita              255826 non-null  float64
#  8   handwashing_facilities      125570 non-null  float64
#  9   total_cases                 293300 non-null  float64
#  10  total_cases_per_million     293300 non-null  float64
#  11  total_vaccinations          77350 non-null   float64
#  12  people_vaccinated           74071 non-null   float64
#  13  people_fully_vaccinated     70622 non-null   float64
#  14  total_boosters              45761 non-null   float64
#  15  total_boosters_per_hundred  45761 non-null   float64
#  16  female_smokers              192280 non-null  float64
#  17  male_smokers                189664 non-null  float64
# dtypes: datetime64[ns](1), float64(13), object(4)
# memory usage: 45.4+ MB

# %%
#Saving clean_df to Resources
clean_df = df
clean_df.to_csv('clean_df-new1.csv',index=False)

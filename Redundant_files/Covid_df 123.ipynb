# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that "admin" database is in MongoDb
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local']

# %%
# assign the admin database to a variable name
db = mongo['admin']

# %%
# review the collections (tables) in our database
print(db.list_collection_names())
# Out:
# ['covid-data', 'system.version', 'covid', 'data-covid']

# %%
# assign the collection to a variable
covid_data = db['covid-data']

# %% [markdown]
# # Clean the Data

# %%
# Retrieve data from the MongoDB collection
results = covid_data.find()

# %%
# Create a Pandas DataFrame
df = pd.DataFrame(results)

# %%
# Print the number of rows in the DataFrame
print('rows in DataFrame:', len(df))
# Out:
# rows in DataFrame: 3546

# %%
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#                         _id iso_code continent     location        date  \
# 0  64d29d73c7e1b733c9309436      AFG      Asia  Afghanistan  01/04/2020
# 1  64d29d73c7e1b733c9309437      AFG      Asia  Afghanistan  01/07/2020
# 2  64d29d73c7e1b733c9309438      AFG      Asia  Afghanistan  01/10/2020
# 3  64d29d73c7e1b733c9309439      AFG      Asia  Afghanistan  01/01/2021
# 4  64d29d73c7e1b733c930943a      AFG      Asia  Afghanistan  01/04/2021
# 5  64d29d73c7e1b733c930943b      AFG      Asia  Afghanistan  01/07/2021
# 6  64d29d73c7e1b733c930943c      AFG      Asia  Afghanistan  01/10/2021
# 7  64d29d73c7e1b733c930943d      AFG      Asia  Afghanistan  01/01/2022
# 8  64d29d73c7e1b733c930943e      AFG      Asia  Afghanistan  01/04/2022
# 9  64d29d73c7e1b733c930943f      AFG      Asia  Afghanistan  01/07/2022
#
#    new_deaths  total_cases_per_million  median_age  aged_65_older  \
# 0         0.0                    4.036        18.6          2.581
# 1         2.0                  762.459        18.6          2.581
# 2         0.0                  954.757        18.6          2.581
# 3        12.0                 1276.795        18.6          2.581
# 4         5.0                 1374.148        18.6          2.581
# 5        91.0                 2922.917        18.6          2.581
# 6         2.0                 3770.329        18.6          2.581
# 7         0.0                 3843.027        18.6          2.581
# 8         5.0                 4321.719        18.6          2.581
# 9         1.0                 4437.964        18.6          2.581
#
#    gdp_per_capita  ...  total_vaccinations  people_vaccinated  \
# 0        1803.987  ...                 NaN                NaN
# 1        1803.987  ...                 NaN                NaN
# 2        1803.987  ...                 NaN                NaN
# 3        1803.987  ...                 NaN                NaN
# 4        1803.987  ...                 NaN                NaN
# 5        1803.987  ...                 NaN                NaN
# 6        1803.987  ...                 NaN                NaN
# 7        1803.987  ...                 NaN                NaN
# 8        1803.987  ...                 NaN                NaN
# 9        1803.987  ...                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  extreme_poverty  female_smokers  \
# 0                      NaN             NaN              NaN             NaN
# 1                      NaN             NaN              NaN             NaN
# 2                      NaN             NaN              NaN             NaN
# 3                      NaN             NaN              NaN             NaN
# 4                      NaN             NaN              NaN             NaN
# 5                      NaN             NaN              NaN             NaN
# 6                      NaN             NaN              NaN             NaN
# 7                      NaN             NaN              NaN             NaN
# 8                      NaN             NaN              NaN             NaN
# 9                      NaN             NaN              NaN             NaN
#
#    male_smokers  hosp_patients_per_million  \
# 0           NaN                        NaN
# 1           NaN                        NaN
# 2           NaN                        NaN
# 3           NaN                        NaN
# 4           NaN                        NaN
# 5           NaN                        NaN
# 6           NaN                        NaN
# 7           NaN                        NaN
# 8           NaN                        NaN
# 9           NaN                        NaN
#
#    excess_mortality_cumulative_absolute  weekly_icu_admissions_per_million
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# 5                                   NaN                                NaN
# 6                                   NaN                                NaN
# 7                                   NaN                                NaN
# 8                                   NaN                                NaN
# 9                                   NaN                                NaN
#
# [10 rows x 22 columns]

# %%
# Examine data type of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3546 entries, 0 to 3545
# Data columns (total 22 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   _id                                   3546 non-null   object
#  1   iso_code                              3546 non-null   object
#  2   continent                             3378 non-null   object
#  3   location                              3546 non-null   object
#  4   date                                  3546 non-null   object
#  5   new_deaths                            3444 non-null   float64
#  6   total_cases_per_million               3281 non-null   float64
#  7   median_age                            2797 non-null   float64
#  8   aged_65_older                         2699 non-null   float64
#  9   gdp_per_capita                        2741 non-null   float64
#  10  handwashing_facilities                1345 non-null   float64
#  11  new_tests_smoothed                    1097 non-null   float64
#  12  total_vaccinations                    780 non-null    float64
#  13  people_vaccinated                     749 non-null    float64
#  14  people_fully_vaccinated               708 non-null    float64
#  15  total_boosters                        470 non-null    float64
#  16  extreme_poverty                       1766 non-null   float64
#  17  female_smokers                        2060 non-null   float64
#  18  male_smokers                          2032 non-null   float64
#  19  hosp_patients_per_million             413 non-null    float64
#  20  excess_mortality_cumulative_absolute  50 non-null     float64
#  21  weekly_icu_admissions_per_million     97 non-null     float64
# dtypes: float64(17), object(5)
# memory usage: 609.6+ KB

# %%
# Change data types for data analysis
df['date'] = pd.to_datetime(df['date'])

# %%
# Confirm type changes were successful by examining data types again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3546 entries, 0 to 3545
# Data columns (total 22 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   _id                                   3546 non-null   object
#  1   iso_code                              3546 non-null   object
#  2   continent                             3378 non-null   object
#  3   location                              3546 non-null   object
#  4   date                                  3546 non-null   datetime64[ns]
#  5   new_deaths                            3444 non-null   float64
#  6   total_cases_per_million               3281 non-null   float64
#  7   median_age                            2797 non-null   float64
#  8   aged_65_older                         2699 non-null   float64
#  9   gdp_per_capita                        2741 non-null   float64
#  10  handwashing_facilities                1345 non-null   float64
#  11  new_tests_smoothed                    1097 non-null   float64
#  12  total_vaccinations                    780 non-null    float64
#  13  people_vaccinated                     749 non-null    float64
#  14  people_fully_vaccinated               708 non-null    float64
#  15  total_boosters                        470 non-null    float64
#  16  extreme_poverty                       1766 non-null   float64
#  17  female_smokers                        2060 non-null   float64
#  18  male_smokers                          2032 non-null   float64
#  19  hosp_patients_per_million             413 non-null    float64
#  20  excess_mortality_cumulative_absolute  50 non-null     float64
#  21  weekly_icu_admissions_per_million     97 non-null     float64
# dtypes: datetime64[ns](1), float64(17), object(4)
# memory usage: 609.6+ KB

# %%
#Saving clean_df to Resources
clean_df = df
clean_df.to_csv('clean_df123.csv',index=False)

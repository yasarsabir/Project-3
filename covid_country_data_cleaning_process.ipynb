# %%
import pandas as pd

# %%
#creating the paths to the covid and country files

world_country_path = 'world_country_lat_long.csv'
covid_data_path = 'owid-covid-data-filtered.csv'

# %%
#reading the country data into pandas dataframe
world_country_df = pd.read_csv('world_country_lat_long.csv')

world_country_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 #reading the country data into pandas dataframe
# ----> 2 world_country_df = pd.read_csv('world_country_lat_long.csv')
#       4 world_country_df.head()
#
# ...

# %%
# selecting the country,latitude and longitude columns

country_df = world_country_df[['country','latitude','longitude']]

country_df
# Out:
#                   country   latitude  longitude
# 0                 Andorra  42.546245   1.601554
# 1    United Arab Emirates  23.424076  53.847818
# 2             Afghanistan  33.939110  67.709953
# 3     Antigua and Barbuda  17.060816 -61.796428
# 4                Anguilla  18.220554 -63.068615
# ..                    ...        ...        ...
# 240                 Yemen  15.552727  48.516388
# 241               Mayotte -12.827500  45.166244
# 242          South Africa -30.559482  22.937506
# 243                Zambia -13.133897  27.849332
# 244              Zimbabwe -19.015438  29.154857
#
# [245 rows x 3 columns]

# %%
#checking for missing values

missing_values = country_df.isnull().sum()

missing_values
# Out:
# country      0
# latitude     1
# longitude    1
# dtype: int64

# %%
#removing the row with no latitude and longitude data

country_df = country_df[country_df['country'] != 'U.S. Minor Outlying Islands']

# %%
#verifying missing data

missing_values = country_df.isnull().sum()

missing_values
# Out:
# country      0
# latitude     0
# longitude    0
# dtype: int64

# %%
#reading the covid data into pandas dataframe

covid_df = pd.read_csv(covid_data_path)

covid_df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  01/04/2020        166.0       52.0
# 1      AFG      Asia  Afghanistan  01/07/2020      31359.0      121.0
# 2      AFG      Asia  Afghanistan  01/10/2020      39268.0       14.0
# 3      AFG      Asia  Afghanistan  01/01/2021      52513.0      183.0
# 4      AFG      Asia  Afghanistan  01/04/2021      56517.0       63.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0              17.714           4.0         0.0                0.429  ...
# 1             268.286         735.0         2.0               16.714  ...
# 2              17.571        1458.0         0.0                1.714  ...
# 3             131.143        2201.0        12.0                9.429  ...
# 4              41.571        2489.0         5.0                3.143  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
#renaming the covid data column to ensure that the name tallies with the country data column 
covid_df= covid_df.rename(columns = {'location':'country'})

covid_df.head()
# Out:
#   iso_code continent      country        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  01/04/2020        166.0       52.0
# 1      AFG      Asia  Afghanistan  01/07/2020      31359.0      121.0
# 2      AFG      Asia  Afghanistan  01/10/2020      39268.0       14.0
# 3      AFG      Asia  Afghanistan  01/01/2021      52513.0      183.0
# 4      AFG      Asia  Afghanistan  01/04/2021      56517.0       63.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0              17.714           4.0         0.0                0.429  ...
# 1             268.286         735.0         2.0               16.714  ...
# 2              17.571        1458.0         0.0                1.714  ...
# 3             131.143        2201.0        12.0                9.429  ...
# 4              41.571        2489.0         5.0                3.143  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
merged_df = pd.merge(covid_df, country_df, on= 'country', how= 'left')

merged_df.head()
# Out:
#   iso_code continent      country        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  01/04/2020        166.0       52.0
# 1      AFG      Asia  Afghanistan  01/07/2020      31359.0      121.0
# 2      AFG      Asia  Afghanistan  01/10/2020      39268.0       14.0
# 3      AFG      Asia  Afghanistan  01/01/2021      52513.0      183.0
# 4      AFG      Asia  Afghanistan  01/04/2021      56517.0       63.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0              17.714           4.0         0.0                0.429  ...
# 1             268.286         735.0         2.0               16.714  ...
# 2              17.571        1458.0         0.0                1.714  ...
# 3             131.143        2201.0        12.0                9.429  ...
# 4              41.571        2489.0         5.0                3.143  ...
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# ...

# %%
merged_df.tail()
# Out:
#      iso_code continent   country        date  total_cases  new_cases  \
# 3541      ZWE    Africa  Zimbabwe  01/07/2022     255586.0        0.0
# 3542      ZWE    Africa  Zimbabwe  01/10/2022     257465.0        0.0
# 3543      ZWE    Africa  Zimbabwe  01/01/2023     260146.0       46.0
# 3544      ZWE    Africa  Zimbabwe  01/04/2023     264549.0        7.0
# 3545      ZWE    Africa  Zimbabwe  01/07/2023     265524.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 3541              48.571        5555.0         0.0                1.286  ...
# 3542              21.000        5602.0         0.0                0.429  ...
# 3543              28.857        5639.0         2.0                0.571  ...
# 3544               5.857        5681.0         0.0                0.286  ...
# 3545              15.857        5707.0         0.0                0.000  ...
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# ...

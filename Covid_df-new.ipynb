# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that "admin" database is in MongoDb
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local']

# %%
# assign the admin database to a variable name
db = mongo['admin']

# %%
# review the collections (tables) in our database
print(db.list_collection_names())
# Out:
# ['covid-data', 'system.version', 'covid', 'data-covid']

# %%
# assign the collection to a variable
covid_data = db['covid-data']

# %% [markdown]
# # Clean the Data

# %%
# Retrieve data from the MongoDB collection
results = covid_data.find()

# %%
# Create a Pandas DataFrame
df = pd.DataFrame(results)

# %%
# Print the number of rows in the DataFrame
print('rows in DataFrame:', len(df))
# Out:
# rows in DataFrame: 330696

# %%
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#                         _id iso_code continent     location        date  \
# 0  64d559ae041874b85a853f70      AFG      Asia  Afghanistan  2020-01-03
# 1  64d559ae041874b85a853f71      AFG      Asia  Afghanistan  2020-01-04
# 2  64d559ae041874b85a853f72      AFG      Asia  Afghanistan  2020-01-05
# 3  64d559ae041874b85a853f73      AFG      Asia  Afghanistan  2020-01-06
# 4  64d559ae041874b85a853f74      AFG      Asia  Afghanistan  2020-01-07
# 5  64d559ae041874b85a853f75      AFG      Asia  Afghanistan  2020-01-08
# 6  64d559ae041874b85a853f76      AFG      Asia  Afghanistan  2020-01-09
# 7  64d559ae041874b85a853f77      AFG      Asia  Afghanistan  2020-01-10
# 8  64d559ae041874b85a853f78      AFG      Asia  Afghanistan  2020-01-11
# 9  64d559ae041874b85a853f79      AFG      Asia  Afghanistan  2020-01-12
#
#    stringency_index  median_age  gdp_per_capita  handwashing_facilities  \
# 0               0.0        18.6        1803.987                  37.746
# 1               0.0        18.6        1803.987                  37.746
# 2               0.0        18.6        1803.987                  37.746
# 3               0.0        18.6        1803.987                  37.746
# 4               0.0        18.6        1803.987                  37.746
# 5               0.0        18.6        1803.987                  37.746
# 6               0.0        18.6        1803.987                  37.746
# 7               0.0        18.6        1803.987                  37.746
# 8               0.0        18.6        1803.987                  37.746
# 9               0.0        18.6        1803.987                  37.746
#
#    total_cases  total_cases_per_million  total_deaths  total_vaccinations  \
# 0          NaN                      NaN           NaN                 NaN
# 1          NaN                      NaN           NaN                 NaN
# 2          NaN                      NaN           NaN                 NaN
# 3          NaN                      NaN           NaN                 NaN
# 4          NaN                      NaN           NaN                 NaN
# 5          NaN                      NaN           NaN                 NaN
# 6          NaN                      NaN           NaN                 NaN
# 7          NaN                      NaN           NaN                 NaN
# 8          NaN                      NaN           NaN                 NaN
# 9          NaN                      NaN           NaN                 NaN
#
#    people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                NaN                      NaN             NaN
# 1                NaN                      NaN             NaN
# 2                NaN                      NaN             NaN
# 3                NaN                      NaN             NaN
# 4                NaN                      NaN             NaN
# 5                NaN                      NaN             NaN
# 6                NaN                      NaN             NaN
# 7                NaN                      NaN             NaN
# 8                NaN                      NaN             NaN
# 9                NaN                      NaN             NaN
#
#    total_boosters_per_hundred  female_smokers  male_smokers
# 0                         NaN             NaN           NaN
# 1                         NaN             NaN           NaN
# 2                         NaN             NaN           NaN
# 3                         NaN             NaN           NaN
# 4                         NaN             NaN           NaN
# 5                         NaN             NaN           NaN
# 6                         NaN             NaN           NaN
# 7                         NaN             NaN           NaN
# 8                         NaN             NaN           NaN
# 9                         NaN             NaN           NaN

# %%
# Examine data type of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330696 entries, 0 to 330695
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   _id                         330696 non-null  object
#  1   iso_code                    330696 non-null  object
#  2   continent                   315000 non-null  object
#  3   location                    330696 non-null  object
#  4   date                        330696 non-null  object
#  5   stringency_index            197651 non-null  float64
#  6   median_age                  261029 non-null  float64
#  7   gdp_per_capita              255826 non-null  float64
#  8   handwashing_facilities      125570 non-null  float64
#  9   total_cases                 293300 non-null  float64
#  10  total_cases_per_million     293300 non-null  float64
#  11  total_deaths                272174 non-null  float64
#  12  total_vaccinations          77350 non-null   float64
#  13  people_vaccinated           74071 non-null   float64
#  14  people_fully_vaccinated     70622 non-null   float64
#  15  total_boosters              45761 non-null   float64
#  16  total_boosters_per_hundred  45761 non-null   float64
#  17  female_smokers              192280 non-null  float64
#  18  male_smokers                189664 non-null  float64
# dtypes: float64(14), object(5)
# memory usage: 47.9+ MB

# %%
# Change data types for data analysis
df['date'] = pd.to_datetime(df['date'])

# %%
# Confirm type changes were successful by examining data types again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330696 entries, 0 to 330695
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   _id                         330696 non-null  object
#  1   iso_code                    330696 non-null  object
#  2   continent                   315000 non-null  object
#  3   location                    330696 non-null  object
#  4   date                        330696 non-null  datetime64[ns]
#  5   stringency_index            197651 non-null  float64
#  6   median_age                  261029 non-null  float64
#  7   gdp_per_capita              255826 non-null  float64
#  8   handwashing_facilities      125570 non-null  float64
#  9   total_cases                 293300 non-null  float64
#  10  total_cases_per_million     293300 non-null  float64
#  11  total_deaths                272174 non-null  float64
#  12  total_vaccinations          77350 non-null   float64
#  13  people_vaccinated           74071 non-null   float64
#  14  people_fully_vaccinated     70622 non-null   float64
#  15  total_boosters              45761 non-null   float64
#  16  total_boosters_per_hundred  45761 non-null   float64
#  17  female_smokers              192280 non-null  float64
#  18  male_smokers                189664 non-null  float64
# dtypes: datetime64[ns](1), float64(14), object(4)
# memory usage: 47.9+ MB

# %%
#Getting rid of missing values (NaN) using drop, inplace=true saves the 'dropped' data
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4190 entries, 4612 to 330398
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _id                         4190 non-null   object
#  1   iso_code                    4190 non-null   object
#  2   continent                   4190 non-null   object
#  3   location                    4190 non-null   object
#  4   date                        4190 non-null   datetime64[ns]
#  5   stringency_index            4190 non-null   float64
#  6   median_age                  4190 non-null   float64
#  7   gdp_per_capita              4190 non-null   float64
#  8   handwashing_facilities      4190 non-null   float64
#  9   total_cases                 4190 non-null   float64
#  10  total_cases_per_million     4190 non-null   float64
#  11  total_deaths                4190 non-null   float64
#  12  total_vaccinations          4190 non-null   float64
#  13  people_vaccinated           4190 non-null   float64
#  14  people_fully_vaccinated     4190 non-null   float64
#  15  total_boosters              4190 non-null   float64
#  16  total_boosters_per_hundred  4190 non-null   float64
#  17  female_smokers              4190 non-null   float64
#  18  male_smokers                4190 non-null   float64
# dtypes: datetime64[ns](1), float64(14), object(4)
# memory usage: 654.7+ KB

# %%
df.head()
# Out:
#                            _id iso_code continent location       date  \
# 4612  64d559af041874b85a855174      DZA    Africa  Algeria 2021-11-21
# 4616  64d559af041874b85a855178      DZA    Africa  Algeria 2021-11-25
# 4620  64d559af041874b85a85517c      DZA    Africa  Algeria 2021-11-29
# 4720  64d559af041874b85a8551e0      DZA    Africa  Algeria 2022-03-09
# 4766  64d559af041874b85a85520e      DZA    Africa  Algeria 2022-04-24
#
#       stringency_index  median_age  gdp_per_capita  handwashing_facilities  \
# 4612             39.81        29.1       13913.839                  83.741
# 4616             39.81        29.1       13913.839                  83.741
# 4620             50.00        29.1       13913.839                  83.741
# 4720             33.59        29.1       13913.839                  83.741
# 4766             33.44        29.1       13913.839                  83.741
#
#       total_cases  total_cases_per_million  total_deaths  total_vaccinations  \
# 4612     208839.0                 4650.868        6017.0          12008974.0
# 4616     209463.0                 4664.765        6035.0          12076870.0
# 4620     210152.0                 4680.109        6058.0          12145830.0
# 4720     265323.0                 5908.773        6858.0          13704895.0
# 4766     265761.0                 5918.528        6874.0          13772044.0
#
#       people_vaccinated  people_fully_vaccinated  total_boosters  \
# 4612          6697263.0                5298544.0         13167.0
# 4616          6716299.0                5340231.0         20340.0
# 4620          6740064.0                5380385.0         25381.0
# 4720          7461932.0                6110712.0        490676.0
# 4766          7840131.0                6481186.0        514063.0
#
#       total_boosters_per_hundred  female_smokers  male_smokers
# 4612                        0.03             0.7          30.4
# 4616                        0.05             0.7          30.4
# 4620                        0.06             0.7          30.4
# 4720                        1.09             0.7          30.4
# 4766                        1.14             0.7          30.4

# %%
#Saving clean_df to Resources
clean_df = df
clean_df.to_csv('clean_df-new.csv',index=False)
